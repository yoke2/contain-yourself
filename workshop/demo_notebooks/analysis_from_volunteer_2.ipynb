# %% [markdown]
# # Python Demo: Analysis From Volunteer 2

# %% [markdown]
# ## Get Data

# %%
# Get data from json file (originally from data.gov.sg)
import pandas as pd
import json

data = json.load(open('blood_donation.json'))
df = pd.DataFrame.from_records(data['result']['records'])
df['count'] = pd.to_numeric(df['count'])
df
# Out:
#    _id   count type_of_donation  year
# 0    1   99355      Whole Blood  2010
# 1    2   10685        Apheresis  2010
# 2    3  104895      Whole Blood  2011
# 3    4   10229        Apheresis  2011
# 4    5  108593      Whole Blood  2012
# 5    6    9980        Apheresis  2012
# 6    7  111626      Whole Blood  2013
# 7    8    9734        Apheresis  2013
# 8    9  108058      Whole Blood  2014
# 9   10    9337        Apheresis  2014

# %% [markdown]
# ### Calculate percentage per type for each year

# %%
df['percentage'] = [round(((row['count']*100)/sum(df[df['year']==row['year']]['count'])),2) for index, row in df.iterrows()]
df
# Out:
#    _id   count type_of_donation  year  percentage
# 0    1   99355      Whole Blood  2010       90.29
# 1    2   10685        Apheresis  2010        9.71
# 2    3  104895      Whole Blood  2011       91.11
# 3    4   10229        Apheresis  2011        8.89
# 4    5  108593      Whole Blood  2012       91.58
# 5    6    9980        Apheresis  2012        8.42
# 6    7  111626      Whole Blood  2013       91.98
# 7    8    9734        Apheresis  2013        8.02
# 8    9  108058      Whole Blood  2014       92.05
# 9   10    9337        Apheresis  2014        7.95

# %% [markdown]
# ## Demo Interactive Graphics with Bokeh

# %% [markdown]
# ### Bokeh Setup

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure
from bokeh.charts import Bar

output_notebook()
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="870e347a-94f0-48f3-ae53-1122ae7893a9">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Create Stacked Bar Chart

# %%
color_palette = ["#e56939", "#3b2fc4"]

data = {
    'type_of_donation': df['type_of_donation'].tolist(),
    'year': df['year'].tolist(),
    'percentage': df['percentage'].tolist()
}

bar = Bar(data, 
          values='percentage', 
          label='year', 
          stack='type_of_donation', 
          agg='sum',
          title="Donation Percentage Per Type Per Year",
          legend='top_right', 
          plot_width=900,
          plot_height=500,
          color=color_palette
         )

hover=HoverTool(tooltips=[("Type of Donation","@type_of_donation"),("Donation Percentage (%)","@height")])
bar.add_tools(hover)

show(bar)
# Out:
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='137fd84d-ff59-4f86-a871-65ed2a01762d', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='44f3bbee-f57b-41a1-9585-154b48f1bc61', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='575cba87-0429-4254-9e0b-9606ebcba80c', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5b711da3-befa-4e94-8a28-7f4694cbc09a', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5d3ff7a4-17c0-4dfd-ab8b-1c028695c81d', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='89dd7b37-8f0c-4530-88d3-d277d25ab670', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='dac7d481-1b8f-418d-b5e5-aaa692b41b2d', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='df41be8f-c918-4c7b-9564-85f220a9d90c', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='ed3f8d15-7d17-4dc5-ba48-35a9946de2c3', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='f8f90dcd-a604-4a4c-8494-be962e87174d', ...)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="13ea2a54-fcb8-4c6e-98c5-6d8ed2285dee"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("13ea2a54-fcb8-4c6e-98c5-6d8ed2285dee");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("13ea2a54-fcb8-4c6e-98c5-6d8ed2285dee");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '13ea2a54-fcb8-4c6e-98c5-6d8ed2285dee' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a07eb192-f0d2-490d-8250-727c2365b6ce":{"roots":{"references":[{"attributes":{"callback":null,"tooltips":[["Type of Donation","@type_of_donation"],["Donation Percentage (%)","@height"]]},"id":"57fc3bff-201c-4acb-ad96-1dfe7ddee3e8","type":"HoverTool"},{"attributes":{"label":{"value":"Apheresis"},"renderers":[{"id":"ed3f8d15-7d17-4dc5-ba48-35a9946de2c3","type":"GlyphRenderer"}]},"id":"f4b1abd6-91f2-44d5-b22c-fe895e283279","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["color","line_color","line_alpha","height","label","width","y","fill_alpha","x"],"data":{"chart_index":[{"type_of_donation":"Whole Blood","year":"2012"}],"color":["#3b2fc4"],"fill_alpha":[0.8],"height":[91.58],"label":[{"type_of_donation":"Whole Blood","year":"2012"}],"line_alpha":[1.0],"line_color":["white"],"type_of_donation":["Whole Blood"],"width":[0.8],"x":["2012"],"y":[45.79],"year":["2012"]}},"id":"bf73871b-d0a7-4c13-bd39-2c351758fdf2","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["color","line_color","line_alpha","height","label","width","y","fill_alpha","x"],"data":{"chart_index":[{"type_of_donation":"Whole Blood","year":"2011"}],"color":["#3b2fc4"],"fill_alpha":[0.8],"height":[91.11],"label":[{"type_of_donation":"Whole Blood","year":"2011"}],"line_alpha":[1.0],"line_color":["white"],"type_of_donation":["Whole Blood"],"width":[0.8],"x":["2011"],"y":[45.555],"year":["2011"]}},"id":"f84200bd-0ced-4ece-9cae-58128a652a66","type":"ColumnDataSource"},{"attributes":{},"id":"1e8babf4-2b94-4146-b79e-ca6377edc726","type":"ResetTool"},{"attributes":{"axis_label":"Sum( Percentage )","formatter":{"id":"f9c4ab5b-99af-4d78-a7c8-cfc73ef75d66","type":"BasicTickFormatter"},"plot":{"id":"a411e0a2-1058-4eef-b2a2-46ecb778ea10","subtype":"Chart","type":"Plot"},"ticker":{"id":"629abe82-3c42-45a2-b4cc-8c7b44691dc8","type":"BasicTicker"}},"id":"85b638c6-4225-4f41-9c88-92f0115e2066","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e1bb1e4-5ae2-44d6-b224-ec8eb6fe466d","type":"Rect"},{"attributes":{"source":null},"id":"ea5dfa0f-7b43-4a91-a8d8-f55af022cdbd","type":"CDSView"},{"attributes":{"below":[{"id":"4e8d2da5-9f67-42f4-82bd-3ef075754ba1","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"85b638c6-4225-4f41-9c88-92f0115e2066","type":"LinearAxis"}],"plot_height":500,"plot_width":900,"renderers":[{"id":"e2067edc-6906-42b3-bf96-93d29df591d3","type":"BoxAnnotation"},{"id":"5b711da3-befa-4e94-8a28-7f4694cbc09a","type":"GlyphRenderer"},{"id":"ed3f8d15-7d17-4dc5-ba48-35a9946de2c3","type":"GlyphRenderer"},{"id":"44f3bbee-f57b-41a1-9585-154b48f1bc61","type":"GlyphRenderer"},{"id":"575cba87-0429-4254-9e0b-9606ebcba80c","type":"GlyphRenderer"},{"id":"137fd84d-ff59-4f86-a871-65ed2a01762d","type":"GlyphRenderer"},{"id":"f8f90dcd-a604-4a4c-8494-be962e87174d","type":"GlyphRenderer"},{"id":"dac7d481-1b8f-418d-b5e5-aaa692b41b2d","type":"GlyphRenderer"},{"id":"89dd7b37-8f0c-4530-88d3-d277d25ab670","type":"GlyphRenderer"},{"id":"df41be8f-c918-4c7b-9564-85f220a9d90c","type":"GlyphRenderer"},{"id":"5d3ff7a4-17c0-4dfd-ab8b-1c028695c81d","type":"GlyphRenderer"},{"id":"0a596696-62e3-4e71-97e9-9c311bf794c1","type":"Legend"},{"id":"4e8d2da5-9f67-42f4-82bd-3ef075754ba1","type":"CategoricalAxis"},{"id":"85b638c6-4225-4f41-9c88-92f0115e2066","type":"LinearAxis"},{"id":"adc6bc32-817f-43c3-85c9-09e3d2462f5e","type":"Grid"}],"title":{"id":"8283b8d9-6640-4822-a8fe-f5dfcfaa99b1","type":"Title"},"toolbar":{"id":"94aa9b96-182f-4c72-8393-2dbb97c50ffa","type":"Toolbar"},"x_range":{"id":"5c0cd797-a419-4826-bfe8-21884d6644a8","type":"FactorRange"},"x_scale":{"id":"47403e87-79b0-424d-848d-62de5cdf3aea","type":"CategoricalScale"},"y_range":{"id":"f779a727-dd1f-4169-b588-ff02c9c702d0","type":"Range1d"},"y_scale":{"id":"870 ...
